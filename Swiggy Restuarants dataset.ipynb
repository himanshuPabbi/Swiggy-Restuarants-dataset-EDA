# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("swiggy.csv")

# %%
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
df=df.drop("ID",axis=1)

# %%
df
# Out:
#                         Area       City                Restaurant  Price  \
# 0                Koramangala  Bangalore               Tandoor Hut  300.0
# 1                Koramangala  Bangalore             Tunday Kababi  300.0
# 2                  Jogupalya  Bangalore                   Kim Lee  650.0
# 3                Indiranagar  Bangalore         New Punjabi Hotel  250.0
# 4                Indiranagar  Bangalore                       Nh8  350.0
# ...                      ...        ...                       ...    ...
# 8675  Panjarapole Cross Road  Ahmedabad                Malt Pizza  500.0
# 8676                  Rohini      Delhi  Jay Mata Ji Home Kitchen  200.0
# 8677                  Rohini      Delhi      Chinese Kitchen King  150.0
# 8678                  Rohini      Delhi    Shree Ram Paratha Wala  150.0
# 8679             Navrangpura  Ahmedabad              Sassy Street  250.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                         Area       City                Restaurant  Price  \
# 0                Koramangala  Bangalore               Tandoor Hut  300.0
# 1                Koramangala  Bangalore             Tunday Kababi  300.0
# 2                  Jogupalya  Bangalore                   Kim Lee  650.0
# 3                Indiranagar  Bangalore         New Punjabi Hotel  250.0
# 4                Indiranagar  Bangalore                       Nh8  350.0
# ...                      ...        ...                       ...    ...
# 8675  Panjarapole Cross Road  Ahmedabad                Malt Pizza  500.0
# 8676                  Rohini      Delhi  Jay Mata Ji Home Kitchen  200.0
# 8677                  Rohini      Delhi      Chinese Kitchen King  150.0
# 8678                  Rohini      Delhi    Shree Ram Paratha Wala  150.0
# 8679             Navrangpura  Ahmedabad              Sassy Street  250.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# ...

# %%
df.isnull().sum()
# Out:
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8679 entries, 0 to 8679
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           8679 non-null   object
#  1   City           8679 non-null   object
#  2   Restaurant     8679 non-null   object
#  3   Price          8679 non-null   float64
#  4   Avg ratings    8679 non-null   float64
#  5   Total ratings  8679 non-null   int64
#  6   Food type      8679 non-null   object
#  7   Address        8679 non-null   object
#  8   Delivery time  8679 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 678.0+ KB

# %%
df.describe()
# Out:
#              Price  Avg ratings  Total ratings  Delivery time
# count  8679.000000  8679.000000    8679.000000    8679.000000
# mean    348.473096     3.655191     156.643623      53.964051
# std     230.937979     0.647615     391.469703      14.290426
# min       0.000000     2.000000      20.000000      20.000000
# 25%     200.000000     2.900000      50.000000      44.000000
# 50%     300.000000     3.900000      80.000000      53.000000
# 75%     400.000000     4.200000     100.000000      64.000000
# max    2500.000000     5.000000   10000.000000     109.000000

# %%
sns.boxplot(df['Price'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
q1=df['Price'].quantile(0.25)

# %%
q3=df['Price'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Price']>lower) & (df['Price']<upper)]

# %%
df
# Out:
#                         Area       City                Restaurant  Price  \
# 0                Koramangala  Bangalore               Tandoor Hut  300.0
# 1                Koramangala  Bangalore             Tunday Kababi  300.0
# 2                  Jogupalya  Bangalore                   Kim Lee  650.0
# 3                Indiranagar  Bangalore         New Punjabi Hotel  250.0
# 4                Indiranagar  Bangalore                       Nh8  350.0
# ...                      ...        ...                       ...    ...
# 8675  Panjarapole Cross Road  Ahmedabad                Malt Pizza  500.0
# 8676                  Rohini      Delhi  Jay Mata Ji Home Kitchen  200.0
# 8677                  Rohini      Delhi      Chinese Kitchen King  150.0
# 8678                  Rohini      Delhi    Shree Ram Paratha Wala  150.0
# 8679             Navrangpura  Ahmedabad              Sassy Street  250.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# ...

# %%
sns.boxplot(df['Avg ratings'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Avg ratings'>

# %%
sns.boxplot(df['Delivery time'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Delivery time'>

# %%
q1=df['Delivery time'].quantile(0.25)

# %%
q3=df['Delivery time'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Delivery time']>lower) & (df['Delivery time']<upper)]

# %%
df
# Out:
#                         Area       City                Restaurant  Price  \
# 0                Koramangala  Bangalore               Tandoor Hut  300.0
# 1                Koramangala  Bangalore             Tunday Kababi  300.0
# 2                  Jogupalya  Bangalore                   Kim Lee  650.0
# 3                Indiranagar  Bangalore         New Punjabi Hotel  250.0
# 4                Indiranagar  Bangalore                       Nh8  350.0
# ...                      ...        ...                       ...    ...
# 8675  Panjarapole Cross Road  Ahmedabad                Malt Pizza  500.0
# 8676                  Rohini      Delhi  Jay Mata Ji Home Kitchen  200.0
# 8677                  Rohini      Delhi      Chinese Kitchen King  150.0
# 8678                  Rohini      Delhi    Shree Ram Paratha Wala  150.0
# 8679             Navrangpura  Ahmedabad              Sassy Street  250.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# ...

# %%
sns.boxplot(df['Total ratings'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total ratings'>

# %%
q1=df['Total ratings'].quantile(0.25)

# %%
q3=df['Total ratings'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Total ratings']>lower) & (df['Total ratings']<upper)]

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %% [markdown]
# # Highest Rating Resturant in Bangalore

# %%
City_Bangalore_df=df[df['City']=="Bangalore"]

# %%
City_Bangalore_df
# Out:
#                            Area       City  \
# 0                   Koramangala  Bangalore
# 1                   Koramangala  Bangalore
# 2                     Jogupalya  Bangalore
# 4                   Indiranagar  Bangalore
# 7                   Koramangala  Bangalore
# ...                         ...        ...
# 8626                   Majestic  Bangalore
# 8647  Sanjay Nagar New Bel Road  Bangalore
# 8648                  Jayanagar  Bangalore
# 8664                   Majestic  Bangalore
# 8669          Central Bangalore  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
highest_rating_df=City_Bangalore_df[['Restaurant','Avg ratings']]

# %%
highest_rating_df
# Out:
#                                         Restaurant  Avg ratings
# 0                                      Tandoor Hut          4.4
# 1                                    Tunday Kababi          4.1
# 2                                          Kim Lee          4.4
# 4                                              Nh8          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts          4.3
# ...                                            ...          ...
# 8626                                 Mejestic Cafe          2.9
# 8647                              Sri Ramji Sweets          2.9
# 8648                                 Sri Sai Foods          2.9
# 8664                             Himadri Ice Cream          2.9
# 8669                               Bangarpet Chats          2.9
#
# [727 rows x 2 columns]

# %%
top_rating_resturant_df=highest_rating_df.groupby("Restaurant")['Avg ratings'].mean().sort_values(ascending=False)[:10]

# %%
top_rating_resturant_df
# Out:
# Restaurant
# Tricky Shakes                                         5.0
# Creams & Bites                                        5.0
# Keventers Ice Creamery                                4.9
# Frosty Crumble                                        4.9
# Hokart - Soori Chaats                                 4.9
# Subbudus The Snackstop ( Eswaris Homemade Snacks )    4.8
# Krispy Kreme                                          4.7
# Happy Belly Bakes- Cakes And Desserts                 4.7
# Artinci - Indulge Guilt Free!                         4.7
# Natural Ice Cream                                     4.7
# Name: Avg ratings, dtype: float64

# %%
sns.barplot(x=top_rating_resturant_df.values,y=top_rating_resturant_df.index)
plt.show()

# %% [markdown]
# # Fastest Delivery Resturant in Bangalore

# %%
City_Bangalore_df
# Out:
#                            Area       City  \
# 0                   Koramangala  Bangalore
# 1                   Koramangala  Bangalore
# 2                     Jogupalya  Bangalore
# 4                   Indiranagar  Bangalore
# 7                   Koramangala  Bangalore
# ...                         ...        ...
# 8626                   Majestic  Bangalore
# 8647  Sanjay Nagar New Bel Road  Bangalore
# 8648                  Jayanagar  Bangalore
# 8664                   Majestic  Bangalore
# 8669          Central Bangalore  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
fastest_delivery_df=City_Bangalore_df[['Restaurant','Avg ratings','Delivery time']]

# %%
fastest_delivery_df
# Out:
#                                         Restaurant  Avg ratings  Delivery time
# 0                                      Tandoor Hut          4.4             59
# 1                                    Tunday Kababi          4.1             56
# 2                                          Kim Lee          4.4             50
# 4                                              Nh8          4.0             63
# 7     Cupcake Noggins - Cakespastries And Desserts          4.3             57
# ...                                            ...          ...            ...
# 8626                                 Mejestic Cafe          2.9             51
# 8647                              Sri Ramji Sweets          2.9             51
# 8648                                 Sri Sai Foods          2.9             56
# 8664                             Himadri Ice Cream          2.9             40
# 8669                               Bangarpet Chats          2.9             37
#
# [727 rows x 3 columns]

# %%
fastest_delivery_df=fastest_delivery_df.reset_index(drop=True)

# %%
fastest_delivery_df
# Out:
#                                        Restaurant  Avg ratings  Delivery time
# 0                                     Tandoor Hut          4.4             59
# 1                                   Tunday Kababi          4.1             56
# 2                                         Kim Lee          4.4             50
# 3                                             Nh8          4.0             63
# 4    Cupcake Noggins - Cakespastries And Desserts          4.3             57
# ..                                            ...          ...            ...
# 722                                 Mejestic Cafe          2.9             51
# 723                              Sri Ramji Sweets          2.9             51
# 724                                 Sri Sai Foods          2.9             56
# 725                             Himadri Ice Cream          2.9             40
# 726                               Bangarpet Chats          2.9             37
#
# [727 rows x 3 columns]

# %%
fastest_delivery_df=fastest_delivery_df.sort_values(by="Delivery time")

# %%
fastest_delivery_df
# Out:
#                             Restaurant  Avg ratings  Delivery time
# 51                      Domino'S Pizza          4.1             30
# 592                Hari Super Sandwich          4.0             30
# 20                             Bheemas          4.3             31
# 572                  Natural Ice Cream          4.7             31
# 207                       Kanti Sweets          4.4             31
# ..                                 ...          ...            ...
# 57                      The Rendezvous          4.0             70
# 678                    Shanghai Social          2.9             70
# 699  Dna Cuisine-Doctor Nutri Ambrosia          2.9             71
# 707                   89 Express Dhaba          2.9             72
# 528                    Pizza Club 1987          2.9             78
#
# [727 rows x 3 columns]

# %%
fastest_delivery_df=fastest_delivery_df.head(20)

# %%
fastest_delivery_df
# Out:
#                                     Restaurant  Avg ratings  Delivery time
# 51                              Domino'S Pizza          4.1             30
# 592                        Hari Super Sandwich          4.0             30
# 20                                     Bheemas          4.3             31
# 572                          Natural Ice Cream          4.7             31
# 207                               Kanti Sweets          4.4             31
# 17                            Lakeview Milkbar          4.1             31
# 560                             Juice Junction          4.5             31
# 389       Mcdonald'S Gourmet Burger Collection          4.1             32
# 582                            Pai Vihar Grand          4.3             32
# 93                              Airlines Hotel          4.3             32
# 40                                 Kabab Magic          3.3             32
# ...

# %%
fastest_delivery_df=fastest_delivery_df.reset_index(drop=True)

# %%
sns.barplot(x=fastest_delivery_df['Restaurant'],y=fastest_delivery_df['Delivery time'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top Food Type Order in Bangalore

# %%
City_Bangalore_df
# Out:
#                            Area       City  \
# 0                   Koramangala  Bangalore
# 1                   Koramangala  Bangalore
# 2                     Jogupalya  Bangalore
# 4                   Indiranagar  Bangalore
# 7                   Koramangala  Bangalore
# ...                         ...        ...
# 8626                   Majestic  Bangalore
# 8647  Sanjay Nagar New Bel Road  Bangalore
# 8648                  Jayanagar  Bangalore
# 8664                   Majestic  Bangalore
# 8669          Central Bangalore  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
label_df=City_Bangalore_df.groupby("Food type").size().sort_values(ascending=False).index

# %%
value_df=City_Bangalore_df.groupby("Food type").size().sort_values(ascending=False).values

# %%
sns.barplot(x=label_df[:10],y=value_df[:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Number of times Food Order from Top Resturant from Koramangala Area in Bangalore

# %%
City_Bangalore_df
# Out:
#                            Area       City  \
# 0                   Koramangala  Bangalore
# 1                   Koramangala  Bangalore
# 2                     Jogupalya  Bangalore
# 4                   Indiranagar  Bangalore
# 7                   Koramangala  Bangalore
# ...                         ...        ...
# 8626                   Majestic  Bangalore
# 8647  Sanjay Nagar New Bel Road  Bangalore
# 8648                  Jayanagar  Bangalore
# 8664                   Majestic  Bangalore
# 8669          Central Bangalore  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
Koramangala_Area_df=City_Bangalore_df[City_Bangalore_df['Area']=="Koramangala"]

# %%
Koramangala_Area_df
# Out:
#              Area       City                                    Restaurant  \
# 0     Koramangala  Bangalore                                   Tandoor Hut
# 1     Koramangala  Bangalore                                 Tunday Kababi
# 7     Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# 10    Koramangala  Bangalore                           Bamey'S Restro Cafe
# 15    Koramangala  Bangalore                 Aalishan Restaurant & Caterer
# ...           ...        ...                                           ...
# 8137  Koramangala  Bangalore                    Hokart - Special Hot Momos
# 8294  Koramangala  Bangalore                               Khamma Ghani Sa
# 8301  Koramangala  Bangalore                         Hokart - Soori Chaats
# 8506  Koramangala  Bangalore                        Keventers Ice Creamery
# 8600  Koramangala  Bangalore                                   Chaat House
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
avg_rating_df=Koramangala_Area_df[['Restaurant','Avg ratings','Food type']]

# %%
avg_rating_df
# Out:
#                                         Restaurant  Avg ratings  \
# 0                                      Tandoor Hut          4.4
# 1                                    Tunday Kababi          4.1
# 7     Cupcake Noggins - Cakespastries And Desserts          4.3
# 10                             Bamey'S Restro Cafe          4.4
# 15                   Aalishan Restaurant & Caterer          4.3
# ...                                            ...          ...
# 8137                    Hokart - Special Hot Momos          4.3
# 8294                               Khamma Ghani Sa          4.6
# 8301                         Hokart - Soori Chaats          4.9
# 8506                        Keventers Ice Creamery          4.9
# 8600                                   Chaat House          2.9
#
#                                       Food type
# 0     Biryani,Chinese,North Indian,South Indian
# 1                              Mughlai,Lucknowi
# 7         Desserts,British,Bakery,Pizzas,Snacks
# ...

# %%
avg_rating_df=avg_rating_df.reset_index(drop=True)

# %%
avg_rating_df
# Out:
#                                       Restaurant  Avg ratings  \
# 0                                    Tandoor Hut          4.4
# 1                                  Tunday Kababi          4.1
# 2   Cupcake Noggins - Cakespastries And Desserts          4.3
# 3                            Bamey'S Restro Cafe          4.4
# 4                  Aalishan Restaurant & Caterer          4.3
# ..                                           ...          ...
# 86                    Hokart - Special Hot Momos          4.3
# 87                               Khamma Ghani Sa          4.6
# 88                         Hokart - Soori Chaats          4.9
# 89                        Keventers Ice Creamery          4.9
# 90                                   Chaat House          2.9
#
#                                     Food type
# 0   Biryani,Chinese,North Indian,South Indian
# 1                            Mughlai,Lucknowi
# 2       Desserts,British,Bakery,Pizzas,Snacks
# ...

# %%
top_10_rating_df=avg_rating_df.sort_values(by="Avg ratings",ascending=False)[:10]

# %%
top_10_rating_df
# Out:
#                 Restaurant  Avg ratings  \
# 74           Tricky Shakes          5.0
# 89  Keventers Ice Creamery          4.9
# 88   Hokart - Soori Chaats          4.9
# 14             Khawa Karpo          4.6
# 87         Khamma Ghani Sa          4.6
# 21      Khichdi Experiment          4.5
# 61           Salad Matters          4.5
# 27           Xoox Brewmill          4.5
# 65    Dairy Day Ice Creams          4.5
# 34        The Circle Dream          4.4
#
#                                             Food type
# 74                                Ice Cream,Beverages
# 89                                 Ice Cream,Desserts
# 88                 Fast Food,Street Food,Snacks,Chaat
# 14                                            Chinese
# 87                            North Indian,Rajasthani
# 21  Home Food,Indian,Healthy Food,North Indian,Sna...
# 61             Salads,Healthy Food,Desserts,Beverages
# 27  North Indian,Chinese,Pizzas,Continental,Desser...
# ...

# %%
top_10_rating_df=top_10_rating_df.reset_index(drop=True)

# %%
sns.barplot(x=top_10_rating_df['Restaurant'],y=top_10_rating_df['Avg ratings'])
plt.xticks(rotation=90)
plt.show()

# %%
label_df=top_10_rating_df.groupby(['Restaurant','Food type'])['Avg ratings'].mean().sort_values(ascending=False).index

# %%
value_df=top_10_rating_df.groupby(['Restaurant','Food type'])['Avg ratings'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Resturant with minimum price of Food Type from Koramangala Area in Bangalore

# %%
Koramangala_Area_df
# Out:
#              Area       City                                    Restaurant  \
# 0     Koramangala  Bangalore                                   Tandoor Hut
# 1     Koramangala  Bangalore                                 Tunday Kababi
# 7     Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# 10    Koramangala  Bangalore                           Bamey'S Restro Cafe
# 15    Koramangala  Bangalore                 Aalishan Restaurant & Caterer
# ...           ...        ...                                           ...
# 8137  Koramangala  Bangalore                    Hokart - Special Hot Momos
# 8294  Koramangala  Bangalore                               Khamma Ghani Sa
# 8301  Koramangala  Bangalore                         Hokart - Soori Chaats
# 8506  Koramangala  Bangalore                        Keventers Ice Creamery
# 8600  Koramangala  Bangalore                                   Chaat House
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
minimum_price_df=Koramangala_Area_df.sort_values(by="Price")

# %%
minimum_price_df
# Out:
#              Area       City                                    Restaurant  \
# 4593  Koramangala  Bangalore                              The Tasty Planet
# 5049  Koramangala  Bangalore                               Goodness Bakery
# 6406  Koramangala  Bangalore                                   Uday Sweets
# 8301  Koramangala  Bangalore                         Hokart - Soori Chaats
# 7     Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# ...           ...        ...                                           ...
# 460   Koramangala  Bangalore                              Sultans Of Spice
# 1044  Koramangala  Bangalore                               Lot Like Crepes
# 718   Koramangala  Bangalore                                The Rendezvous
# 4442  Koramangala  Bangalore                    The Local-Terrace Drinkery
# 1632  Koramangala  Bangalore                              The Bier Library
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
minimum_price_df=minimum_price_df.head(10)

# %%
minimum_price_df
# Out:
#              Area       City                                    Restaurant  \
# 4593  Koramangala  Bangalore                              The Tasty Planet
# 5049  Koramangala  Bangalore                               Goodness Bakery
# 6406  Koramangala  Bangalore                                   Uday Sweets
# 8301  Koramangala  Bangalore                         Hokart - Soori Chaats
# 7     Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# 8137  Koramangala  Bangalore                    Hokart - Special Hot Momos
# 5690  Koramangala  Bangalore                       Lepcha Darjeeling Momos
# 808   Koramangala  Bangalore                          Chaat Street Express
# 1176  Koramangala  Bangalore                                   Khawa Karpo
# 829   Koramangala  Bangalore                                    Chaska Bun
#
#       Price  Avg ratings  Total ratings  \
# 4593   70.0          2.9             80
# 5049  100.0          2.9             80
# ...

# %%
minimum_price_df=minimum_price_df[['Restaurant','Price','Avg ratings','Food type']]

# %%
minimum_price_df
# Out:
#                                         Restaurant  Price  Avg ratings  \
# 4593                              The Tasty Planet   70.0          2.9
# 5049                               Goodness Bakery  100.0          2.9
# 6406                                   Uday Sweets  100.0          3.9
# 8301                         Hokart - Soori Chaats  150.0          4.9
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 8137                    Hokart - Special Hot Momos  150.0          4.3
# 5690                       Lepcha Darjeeling Momos  150.0          2.9
# 808                           Chaat Street Express  150.0          2.9
# 1176                                   Khawa Karpo  178.0          4.6
# 829                                     Chaska Bun  178.0          4.4
#
#                                               Food type
# 4593                  Beverages,Fast Food,Salads,Snacks
# 5049                                    Bakery,Desserts
# ...

# %%
minimum_price_df=minimum_price_df.reset_index(drop=True)

# %%
minimum_price_df
# Out:
#                                      Restaurant  Price  Avg ratings  \
# 0                              The Tasty Planet   70.0          2.9
# 1                               Goodness Bakery  100.0          2.9
# 2                                   Uday Sweets  100.0          3.9
# 3                         Hokart - Soori Chaats  150.0          4.9
# 4  Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 5                    Hokart - Special Hot Momos  150.0          4.3
# 6                       Lepcha Darjeeling Momos  150.0          2.9
# 7                          Chaat Street Express  150.0          2.9
# 8                                   Khawa Karpo  178.0          4.6
# 9                                    Chaska Bun  178.0          4.4
#
#                                            Food type
# 0                  Beverages,Fast Food,Salads,Snacks
# 1                                    Bakery,Desserts
# 2                                          Fast Food
# ...

# %%
sns.barplot(x=minimum_price_df['Restaurant'],y=minimum_price_df['Price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Resturant with Low Rating from Koramangala Area in Bangalore

# %%
Koramangala_Area_df
# Out:
#              Area       City                                    Restaurant  \
# 0     Koramangala  Bangalore                                   Tandoor Hut
# 1     Koramangala  Bangalore                                 Tunday Kababi
# 7     Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# 10    Koramangala  Bangalore                           Bamey'S Restro Cafe
# 15    Koramangala  Bangalore                 Aalishan Restaurant & Caterer
# ...           ...        ...                                           ...
# 8137  Koramangala  Bangalore                    Hokart - Special Hot Momos
# 8294  Koramangala  Bangalore                               Khamma Ghani Sa
# 8301  Koramangala  Bangalore                         Hokart - Soori Chaats
# 8506  Koramangala  Bangalore                        Keventers Ice Creamery
# 8600  Koramangala  Bangalore                                   Chaat House
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
low_rating_resturant_df=Koramangala_Area_df[['Restaurant','Avg ratings','Price','Food type']]

# %%
low_rating_resturant_df
# Out:
#                                         Restaurant  Avg ratings  Price  \
# 0                                      Tandoor Hut          4.4  300.0
# 1                                    Tunday Kababi          4.1  300.0
# 7     Cupcake Noggins - Cakespastries And Desserts          4.3  150.0
# 10                             Bamey'S Restro Cafe          4.4  400.0
# 15                   Aalishan Restaurant & Caterer          4.3  290.0
# ...                                            ...          ...    ...
# 8137                    Hokart - Special Hot Momos          4.3  150.0
# 8294                               Khamma Ghani Sa          4.6  500.0
# 8301                         Hokart - Soori Chaats          4.9  150.0
# 8506                        Keventers Ice Creamery          4.9  200.0
# 8600                                   Chaat House          2.9  200.0
#
#                                       Food type
# 0     Biryani,Chinese,North Indian,South Indian
# ...

# %%
low_rating_resturant_df=low_rating_resturant_df.sort_values(by="Avg ratings")

# %%
low_rating_resturant_df
# Out:
#                         Restaurant  Avg ratings  Price  \
# 8600                   Chaat House          2.9  200.0
# 3522                Chinese Bistro          2.9  200.0
# 3664  Btc (Bathinda Thali Company)          2.9  300.0
# 3126                   Globo Combo          2.9  300.0
# 4312                 Ruchi Virundu          2.9  250.0
# ...                            ...          ...    ...
# 1176                   Khawa Karpo          4.6  178.0
# 8294               Khamma Ghani Sa          4.6  500.0
# 8301         Hokart - Soori Chaats          4.9  150.0
# 8506        Keventers Ice Creamery          4.9  200.0
# 5936                 Tricky Shakes          5.0  250.0
#
#                                     Food type
# 8600  Beverages,Ice Cream,North Indian,Snacks
# 3522                          Chinese,Biryani
# 3664                                   Indian
# 3126               Chinese,North Indian,Combo
# 4312                     Biryani,South Indian
# ...

# %%
low_rating_resturant_df=low_rating_resturant_df.head(10)

# %%
low_rating_resturant_df
# Out:
#                         Restaurant  Avg ratings  Price  \
# 8600                   Chaat House          2.9  200.0
# 3522                Chinese Bistro          2.9  200.0
# 3664  Btc (Bathinda Thali Company)          2.9  300.0
# 3126                   Globo Combo          2.9  300.0
# 4312                 Ruchi Virundu          2.9  250.0
# 4442    The Local-Terrace Drinkery          2.9  600.0
# 2978                Drunken Monkey          2.9  300.0
# 4593              The Tasty Planet          2.9   70.0
# 4677       Friends Euro Restaurant          2.9  599.0
# 5049               Goodness Bakery          2.9  100.0
#
#                                     Food type
# 8600  Beverages,Ice Cream,North Indian,Snacks
# 3522                          Chinese,Biryani
# 3664                                   Indian
# 3126               Chinese,North Indian,Combo
# 4312                     Biryani,South Indian
# 4442                          American,Indian
# ...

# %%
low_rating_resturant_df=low_rating_resturant_df.reset_index(drop=True)

# %%
sns.barplot(x=low_rating_resturant_df['Restaurant'],y=low_rating_resturant_df['Avg ratings'])
plt.xticks(rotation=90)
plt.show()

# %%
Koramangala_Area_df
# Out:
#              Area       City                                    Restaurant  \
# 0     Koramangala  Bangalore                                   Tandoor Hut
# 1     Koramangala  Bangalore                                 Tunday Kababi
# 7     Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# 10    Koramangala  Bangalore                           Bamey'S Restro Cafe
# 15    Koramangala  Bangalore                 Aalishan Restaurant & Caterer
# ...           ...        ...                                           ...
# 8137  Koramangala  Bangalore                    Hokart - Special Hot Momos
# 8294  Koramangala  Bangalore                               Khamma Ghani Sa
# 8301  Koramangala  Bangalore                         Hokart - Soori Chaats
# 8506  Koramangala  Bangalore                        Keventers Ice Creamery
# 8600  Koramangala  Bangalore                                   Chaat House
#
#       Price  Avg ratings  Total ratings  \
# ...

# %% [markdown]
# # Resturant with minimum total rating  from Koramangala Area in Bangalore

# %%
total_rating_df=Koramangala_Area_df[['Restaurant','Total ratings','Avg ratings']]

# %%
total_rating_df
# Out:
#                                         Restaurant  Total ratings  Avg ratings
# 0                                      Tandoor Hut            100          4.4
# 1                                    Tunday Kababi            100          4.1
# 7     Cupcake Noggins - Cakespastries And Desserts            100          4.3
# 10                             Bamey'S Restro Cafe            100          4.4
# 15                   Aalishan Restaurant & Caterer            100          4.3
# ...                                            ...            ...          ...
# 8137                    Hokart - Special Hot Momos             50          4.3
# 8294                               Khamma Ghani Sa             20          4.6
# 8301                         Hokart - Soori Chaats             20          4.9
# 8506                        Keventers Ice Creamery             20          4.9
# 8600                                   Chaat House             80          2.9
#
# [91 rows x 3 columns]

# %%
total_rating_df=total_rating_df.sort_values(by="Total ratings")

# %%
total_rating_df=total_rating_df.reset_index(drop=True)

# %%
total_rating_df
# Out:
#                            Restaurant  Total ratings  Avg ratings
# 0    Burritos & Bowls Mexican Kitchen             20          4.2
# 1                Dairy Day Ice Creams             20          4.5
# 2                    Brown Burger Co.             20          4.4
# 3                     Basmati Express             20          3.6
# 4           Dande'S Hyderabad Biryani             20          3.3
# ..                                ...            ...          ...
# 86                  Chuckling Chinese            100          4.1
# 87           Southern Soul Restaurant            100          4.1
# 88             Singh Da Punjabi Dhaba            100          3.8
# 89  Lavender Bakery By Fresh Pressery            100          4.3
# 90                 Imperio Restaurant            100          3.9
#
# [91 rows x 3 columns]

# %%
sns.barplot(x=total_rating_df['Restaurant'][:10],y=total_rating_df['Total ratings'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Resturant with maximum total rating  from Koramangala Area in Bangalore

# %%
total_rating_df=Koramangala_Area_df[['Restaurant','Total ratings','Avg ratings']]

# %%
total_rating_df
# Out:
#                                         Restaurant  Total ratings  Avg ratings
# 0                                      Tandoor Hut            100          4.4
# 1                                    Tunday Kababi            100          4.1
# 7     Cupcake Noggins - Cakespastries And Desserts            100          4.3
# 10                             Bamey'S Restro Cafe            100          4.4
# 15                   Aalishan Restaurant & Caterer            100          4.3
# ...                                            ...            ...          ...
# 8137                    Hokart - Special Hot Momos             50          4.3
# 8294                               Khamma Ghani Sa             20          4.6
# 8301                         Hokart - Soori Chaats             20          4.9
# 8506                        Keventers Ice Creamery             20          4.9
# 8600                                   Chaat House             80          2.9
#
# [91 rows x 3 columns]

# %%
total_rating_df=total_rating_df.sort_values(by="Total ratings",ascending=False)

# %%
total_rating_df=total_rating_df.reset_index(drop=True)

# %%
total_rating_df
# Out:
#                            Restaurant  Total ratings  Avg ratings
# 0                         Tandoor Hut            100          4.4
# 1                  Khichdi Experiment            100          4.5
# 2   Lavender Bakery By Fresh Pressery            100          4.3
# 3                  Ajji Ruchi Kitchen            100          4.1
# 4                    Craft Of Biryani            100          4.2
# ..                                ...            ...          ...
# 86                    Basmati Express             20          3.6
# 87                     Kulcha Stories             20          3.8
# 88                     Sera'S Cuisine             20          4.2
# 89          Dande'S Hyderabad Biryani             20          3.3
# 90                     Little Kolkata             20          4.1
#
# [91 rows x 3 columns]

# %%
sns.barplot(x=total_rating_df['Restaurant'][:10],y=total_rating_df['Total ratings'][:10])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %% [markdown]
# # Maximum number of resturants are in which area of Bangalore

# %%
City_Bangalore_df
# Out:
#                            Area       City  \
# 0                   Koramangala  Bangalore
# 1                   Koramangala  Bangalore
# 2                     Jogupalya  Bangalore
# 4                   Indiranagar  Bangalore
# 7                   Koramangala  Bangalore
# ...                         ...        ...
# 8626                   Majestic  Bangalore
# 8647  Sanjay Nagar New Bel Road  Bangalore
# 8648                  Jayanagar  Bangalore
# 8664                   Majestic  Bangalore
# 8669          Central Bangalore  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
resturant_area_df=City_Bangalore_df[['Area','Restaurant','Avg ratings']]

# %%
resturant_area_df
# Out:
#                            Area                                    Restaurant  \
# 0                   Koramangala                                   Tandoor Hut
# 1                   Koramangala                                 Tunday Kababi
# 2                     Jogupalya                                       Kim Lee
# 4                   Indiranagar                                           Nh8
# 7                   Koramangala  Cupcake Noggins - Cakespastries And Desserts
# ...                         ...                                           ...
# 8626                   Majestic                                 Mejestic Cafe
# 8647  Sanjay Nagar New Bel Road                              Sri Ramji Sweets
# 8648                  Jayanagar                                 Sri Sai Foods
# 8664                   Majestic                             Himadri Ice Cream
# 8669          Central Bangalore                               Bangarpet Chats
#
#       Avg ratings
# ...

# %%
resturant_area_df=resturant_area_df.sort_values(by="Area")

# %%
resturant_area_df
# Out:
#                Area                     Restaurant  Avg ratings
# 3155        Adugodi              Pockets And Bowls          2.9
# 3465        Adugodi                 Polamma'S Mess          4.2
# 3121        Adugodi                   Sweet Rascal          2.9
# 2277        Adugodi         Malabar Biriyani World          4.3
# 3120        Adugodi        Dhishoom -Dhaba By Salt          4.3
# ...             ...                            ...          ...
# 2642   Viveka Nagar                  Maven Kitchen          4.6
# 5488       Vv Puram  Upahara Darshini Kims Canteen          4.4
# 2670  Wilson Garden         Namma Kudla Restaurant          4.1
# 2161  Wilson Garden              Karavali Kolimane          3.7
# 3888  Wilson Garden              Garden City Hotel          2.9
#
# [727 rows x 3 columns]

# %%
resturant_area_df['Area'].value_counts()
# Out:
# Indiranagar          100
# Koramangala           91
# Ashok Nagar           66
# Central Bangalore     59
# Basavanagudi          50
#                     ...
# Jayamahal              1
# Neelasandra            1
# Malleswaram            1
# Kadugondanahalli       1
# Sarvagnanagar          1
# Name: Area, Length: 67, dtype: int64

# %%
City_Bangalore_df.groupby("Area").size().sort_values(ascending=False)
# Out:
# Area
# Indiranagar          100
# Koramangala           91
# Ashok Nagar           66
# Central Bangalore     59
# Basavanagudi          50
#                     ...
# Jayamahal              1
# Neelasandra            1
# Malleswaram            1
# Kadugondanahalli       1
# Sarvagnanagar          1
# Length: 67, dtype: int64

# %%
label_df=City_Bangalore_df.groupby("Area").size().sort_values(ascending=False).index

# %%
value_df=City_Bangalore_df.groupby("Area").size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top 5 Food With Maximum Price in  a resturant of bangalore

# %%
City_Bangalore_df
# Out:
#                            Area       City  \
# 0                   Koramangala  Bangalore
# 1                   Koramangala  Bangalore
# 2                     Jogupalya  Bangalore
# 4                   Indiranagar  Bangalore
# 7                   Koramangala  Bangalore
# ...                         ...        ...
# 8626                   Majestic  Bangalore
# 8647  Sanjay Nagar New Bel Road  Bangalore
# 8648                  Jayanagar  Bangalore
# 8664                   Majestic  Bangalore
# 8669          Central Bangalore  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
top_5_food_df=City_Bangalore_df[['Restaurant','Food type','Price']]

# %%
top_5_food_df
# Out:
#                                         Restaurant  \
# 0                                      Tandoor Hut
# 1                                    Tunday Kababi
# 2                                          Kim Lee
# 4                                              Nh8
# 7     Cupcake Noggins - Cakespastries And Desserts
# ...                                            ...
# 8626                                 Mejestic Cafe
# 8647                              Sri Ramji Sweets
# 8648                                 Sri Sai Foods
# 8664                             Himadri Ice Cream
# 8669                               Bangarpet Chats
#
#                                               Food type  Price
# 0             Biryani,Chinese,North Indian,South Indian  300.0
# 1                                      Mughlai,Lucknowi  300.0
# 2                                               Chinese  650.0
# 4     Rajasthani,Gujarati,North Indian,Snacks,Desser...  350.0
# ...

# %%
top_5_food_df=top_5_food_df.sort_values(by="Price",ascending=False)

# %%
top_5_food_df=top_5_food_df.reset_index(drop=True)

# %%
top_5_food_df
# Out:
#                        Restaurant                          Food type  Price
# 0                         Kim Lee                            Chinese  650.0
# 1    Candice'S Gourmet Sandwiches               Continental,American  650.0
# 2                       Hotel Geo                Coastal,Goan,Indian  650.0
# 3                       Dhaba Co.                       North Indian  650.0
# 4                         Jalpaan      Desserts,Italian,Jain,Mexican  650.0
# ..                            ...                                ...    ...
# 722                 Sandwich Guru                   Snacks,Beverages   99.0
# 723              Sri Ramji Sweets                             Sweets   75.0
# 724              The Tasty Planet  Beverages,Fast Food,Salads,Snacks   70.0
# 725                 Sweet Chariot                           Desserts   50.0
# 726                    Cane Fresh          Indian,Beverages,Desserts   50.0
#
# [727 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_5_food_df['Food type'][:10],y=top_5_food_df['Price'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Minimum number of resturants are in which area of Bangalore

# %%
City_Bangalore_df
# Out:
#                            Area       City  \
# 0                   Koramangala  Bangalore
# 1                   Koramangala  Bangalore
# 2                     Jogupalya  Bangalore
# 4                   Indiranagar  Bangalore
# 7                   Koramangala  Bangalore
# ...                         ...        ...
# 8626                   Majestic  Bangalore
# 8647  Sanjay Nagar New Bel Road  Bangalore
# 8648                  Jayanagar  Bangalore
# 8664                   Majestic  Bangalore
# 8669          Central Bangalore  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
resturant_area_df=City_Bangalore_df[['Area','Restaurant','Avg ratings']]

# %%
resturant_area_df
# Out:
#                            Area                                    Restaurant  \
# 0                   Koramangala                                   Tandoor Hut
# 1                   Koramangala                                 Tunday Kababi
# 2                     Jogupalya                                       Kim Lee
# 4                   Indiranagar                                           Nh8
# 7                   Koramangala  Cupcake Noggins - Cakespastries And Desserts
# ...                         ...                                           ...
# 8626                   Majestic                                 Mejestic Cafe
# 8647  Sanjay Nagar New Bel Road                              Sri Ramji Sweets
# 8648                  Jayanagar                                 Sri Sai Foods
# 8664                   Majestic                             Himadri Ice Cream
# 8669          Central Bangalore                               Bangarpet Chats
#
#       Avg ratings
# ...

# %%
resturant_area_df=resturant_area_df.sort_values(by="Area")

# %%
resturant_area_df
# Out:
#                Area                     Restaurant  Avg ratings
# 3155        Adugodi              Pockets And Bowls          2.9
# 3465        Adugodi                 Polamma'S Mess          4.2
# 3121        Adugodi                   Sweet Rascal          2.9
# 2277        Adugodi         Malabar Biriyani World          4.3
# 3120        Adugodi        Dhishoom -Dhaba By Salt          4.3
# ...             ...                            ...          ...
# 2642   Viveka Nagar                  Maven Kitchen          4.6
# 5488       Vv Puram  Upahara Darshini Kims Canteen          4.4
# 2670  Wilson Garden         Namma Kudla Restaurant          4.1
# 2161  Wilson Garden              Karavali Kolimane          3.7
# 3888  Wilson Garden              Garden City Hotel          2.9
#
# [727 rows x 3 columns]

# %%
resturant_area_df['Area'].value_counts()
# Out:
# Indiranagar          100
# Koramangala           91
# Ashok Nagar           66
# Central Bangalore     59
# Basavanagudi          50
#                     ...
# Jayamahal              1
# Neelasandra            1
# Malleswaram            1
# Kadugondanahalli       1
# Sarvagnanagar          1
# Name: Area, Length: 67, dtype: int64

# %%
City_Bangalore_df.groupby("Area").size().sort_values(ascending=True)
# Out:
# Area
# Vv Puram               1
# Halsuru                1
# Residency Road         1
# Ganganagar             1
# Rt Nagar               1
#                     ...
# Basavanagudi          50
# Central Bangalore     59
# Ashok Nagar           66
# Koramangala           91
# Indiranagar          100
# Length: 67, dtype: int64

# %%
label_df=City_Bangalore_df.groupby("Area").size().sort_values(ascending=True).index

# %%
value_df=City_Bangalore_df.groupby("Area").size().sort_values(ascending=True).values

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %% [markdown]
# # Top 10 Resturant With highest average rating in all city and Area

# %%
top_10_resturant_df=df.sort_values(by="Avg ratings",ascending=False)

# %%
top_10_resturant_df
# Out:
#                         Area       City                            Restaurant  \
# 5885            Andheri East     Mumbai                      Nivala Apka Apna
# 5519       Scruz Bandra East     Mumbai                           Cafe Kokomo
# 5798          Himayath Nagar  Hyderabad                   Wallonia Waffle Co.
# 5799          Himayath Nagar  Hyderabad  Splurge - Thickshakes And Milkshakes
# 5800          Himayath Nagar  Hyderabad                     The Liege Waffles
# ...                      ...        ...                                   ...
# 3149               Lake Town    Kolkata                      Diwan Food Court
# 4953  Kausar Baugh Nibm Road       Pune              Hyderabadi Biryani House
# 111                  Adikmet  Hyderabad                            Frosty Den
# 5339          Himayath Nagar  Hyderabad                    The Shawarma Daddy
# 4828                 Kothrud       Pune          Golden Dragon Chinese & Momo
#
# ...

# %%
top_10_resturant_df=top_10_resturant_df.head(10)

# %%
top_10_resturant_df
# Out:
#                    Area       City                            Restaurant  \
# 5885       Andheri East     Mumbai                      Nivala Apka Apna
# 5519  Scruz Bandra East     Mumbai                           Cafe Kokomo
# 5798     Himayath Nagar  Hyderabad                   Wallonia Waffle Co.
# 5799     Himayath Nagar  Hyderabad  Splurge - Thickshakes And Milkshakes
# 5800     Himayath Nagar  Hyderabad                     The Liege Waffles
# 8011       Basavanagudi  Bangalore                        Creams & Bites
# 6538       Shivajinagar       Pune               Shree Krishna Juice Bar
# 5424            Chembur     Mumbai                       Get In My Belly
# 5425            Chembur     Mumbai                    The Asian Pavilion
# 5684            Kothrud       Pune                             Papacream
#
#       Price  Avg ratings  Total ratings                         Food type  \
# 5885  200.0          5.0             20       North Indian,Chinese,Indian
# ...

# %%
label_df=top_10_resturant_df.groupby("Area").size().sort_values(ascending=False).index

# %%
value_df=top_10_resturant_df.groupby("Area").size().sort_values(ascending=False).values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %%
label_df=top_10_resturant_df.groupby("City").size().sort_values(ascending=False).index

# %%
value_df=top_10_resturant_df.groupby("City").size().sort_values(ascending=False).values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f")
plt.show()

# %%
sns.barplot(x=label_df,y=value_df)
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Top 10 Resturant With Fastest Delivery all city and Area

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
top_10_fast_delivery_df=df[['Area',"City",'Restaurant','Delivery time']]

# %%
top_10_fast_delivery_df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Delivery time
# 0                                      Tandoor Hut             59
# 1                                    Tunday Kababi             56
# 2                                          Kim Lee             50
# 4                                              Nh8             63
# 7     Cupcake Noggins - Cakespastries And Desserts             57
# ...                                            ...            ...
# ...

# %%
top_10_fast_delivery_df=top_10_fast_delivery_df.sort_values(by="Delivery time")[:10]

# %%
top_10_fast_delivery_df
# Out:
#                       Area       City  \
# 7240                 Udhna      Surat
# 6905  Venkateshwara Colony  Hyderabad
# 1215                 Paldi  Ahmedabad
# 7029        Santacruz East     Mumbai
# 8114           Narayanguda  Hyderabad
# 7430                 Paldi  Ahmedabad
# 6818          Gulbai Tekra  Ahmedabad
# 4421                Rohini      Delhi
# 4119             Kachiguda  Hyderabad
# 7785                 Udhna      Surat
#
#                                              Restaurant  Delivery time
# 7240                               Sarvottam Restaurant             22
# 6905                                             Scoops             24
# 1215                                 Vadilal Scoop Shop             24
# 7029                                  Apsara Ice Creams             24
# 8114                                      Grameen Kulfi             24
# 7430                                 Paldi Juice Corner             25
# ...

# %%
sns.barplot(x=top_10_fast_delivery_df['City'],y=top_10_fast_delivery_df['Delivery time'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='Delivery time'>

# %%
sns.barplot(x=top_10_fast_delivery_df['Area'],y=top_10_fast_delivery_df['Delivery time'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=top_10_fast_delivery_df['Restaurant'],y=top_10_fast_delivery_df['Delivery time'])
# Out:
# <AxesSubplot:xlabel='Restaurant', ylabel='Delivery time'>

# %% [markdown]
# # Total Number of Resturants for Each City

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
label_df=df.groupby("City").size().sort_values().index

# %%
value_df=df.groupby("City").size().sort_values().values

# %%
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Total Number of Resturants for Food type only Pizzas with highest average ratings

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7018 entries, 0 to 8679
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           7018 non-null   object
#  1   City           7018 non-null   object
#  2   Restaurant     7018 non-null   object
#  3   Price          7018 non-null   float64
#  4   Avg ratings    7018 non-null   float64
#  5   Total ratings  7018 non-null   int64
#  6   Food type      7018 non-null   object
#  7   Address        7018 non-null   object
#  8   Delivery time  7018 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 548.3+ KB

# %%
def Convert(ele):
    lis=ele.split(",")
    if "Pizzas" in lis:
        return 1
    else:
        return 0

# %%
df['Food type pizzas']=df['Food type'].apply(Convert)
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_31004\1276817798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Food type pizzas']=df['Food type'].apply(Convert)

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
food_type_pizzas_df=df[df['Food type pizzas']==1]

# %%
food_type_pizzas_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 8                                         Tea Brew  350.0          4.1
# 67                                       Chaipatty  200.0          3.9
# 108                                       Us Pizza  200.0          3.2
# 111                                     Frosty Den  200.0          2.2
# ...

# %%
food_type_pizzas_df['Food type pizzas'].value_counts()
# Out:
# 1    486
# Name: Food type pizzas, dtype: int64

# %%
food_type_pizzas_avg_rating_top_10_df=food_type_pizzas_df.sort_values(by="Avg ratings",ascending=False)[:10]

# %%
food_type_pizzas_avg_rating_top_10_df
# Out:
#                Area       City             Restaurant  Price  Avg ratings  \
# 6297            Nsp      Delhi              Fat Tiger  300.0          5.0
# 1878         Rohini      Delhi  Pizza Paradise By Vhc  150.0          4.8
# 972          Bopodi       Pune           Rosso Bianco  500.0          4.8
# 3783        Kilpauk    Chennai          Pastry Maniaa  200.0          4.7
# 1781  Koregaon Park       Pune           Yonies Pizza  550.0          4.6
# 1842   Nungambakkam    Chennai             Crisp Cafe  400.0          4.6
# 1856  Koregaon Park       Pune          Huber & Holly  500.0          4.6
# 6524        Kilpauk    Chennai            Bombaysthan  250.0          4.6
# 3746       Perambur    Chennai  Chennai Classic Cakes  250.0          4.6
# 827       Vastrapur  Ahmedabad          The Blue Oven  600.0          4.5
#
#       Total ratings                                          Food type  \
# 6297             20           Pizzas,Chinese,Snacks,Beverages,American
# ...

# %%
sns.barplot(x=food_type_pizzas_avg_rating_top_10_df['Restaurant'],y=food_type_pizzas_avg_rating_top_10_df['Avg ratings'])
plt.xticks(rotation=90)
plt.show()

# %%
food_type_pizzas_avg_rating_top_10_df
# Out:
#                Area       City             Restaurant  Price  Avg ratings  \
# 6297            Nsp      Delhi              Fat Tiger  300.0          5.0
# 1878         Rohini      Delhi  Pizza Paradise By Vhc  150.0          4.8
# 972          Bopodi       Pune           Rosso Bianco  500.0          4.8
# 3783        Kilpauk    Chennai          Pastry Maniaa  200.0          4.7
# 1781  Koregaon Park       Pune           Yonies Pizza  550.0          4.6
# 1842   Nungambakkam    Chennai             Crisp Cafe  400.0          4.6
# 1856  Koregaon Park       Pune          Huber & Holly  500.0          4.6
# 6524        Kilpauk    Chennai            Bombaysthan  250.0          4.6
# 3746       Perambur    Chennai  Chennai Classic Cakes  250.0          4.6
# 827       Vastrapur  Ahmedabad          The Blue Oven  600.0          4.5
#
#       Total ratings                                          Food type  \
# 6297             20           Pizzas,Chinese,Snacks,Beverages,American
# ...

# %%
label_df=food_type_pizzas_avg_rating_top_10_df.groupby("City")['Avg ratings'].mean().sort_values(ascending=False).index

# %%
value_df=food_type_pizzas_avg_rating_top_10_df.groupby("City")['Avg ratings'].mean().sort_values(ascending=False).values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Total Number of Resturants for Food type Pizzas with Fastest Delivery

# %%
food_type_pizzas_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 8                                         Tea Brew  350.0          4.1
# 67                                       Chaipatty  200.0          3.9
# 108                                       Us Pizza  200.0          3.2
# 111                                     Frosty Den  200.0          2.2
# ...

# %%
food_type_pizzas_fast_delivery_df=food_type_pizzas_df.sort_values(by="Delivery time")

# %%
food_type_pizzas_fast_delivery_df
# Out:
#                  Area       City             Restaurant  Price  Avg ratings  \
# 7785            Udhna      Surat            Nv Fastfood  150.0          4.0
# 6509  Sector 3 Rohini      Delhi           Pizzallo Hot  400.0          3.0
# 1936     Himayatnagar  Hyderabad          Huber & Holly  500.0          4.2
# 6817     Gulbai Tekra  Ahmedabad           Hocco Eatery  400.0          4.4
# 3579   Himayath Nagar  Hyderabad  Krishna Idli And Dosa  250.0          3.9
# ...               ...        ...                    ...    ...          ...
# 5452         Jadavpur    Kolkata            Go 69 Pizza  250.0          2.9
# 1092            Garfa    Kolkata              Happizzaa  350.0          4.0
# 5288        Annanagar    Chennai        Pizza Mechanics  200.0          2.9
# 8297         Jadavpur    Kolkata                    Cfk  500.0          2.9
# 4496        Lake Town    Kolkata          Kolkata Pizza  159.0          2.9
#
# ...

# %%
food_type_pizzas_fast_delivery_df=food_type_pizzas_fast_delivery_df.reset_index(drop=True)

# %%
food_type_pizzas_fast_delivery_df
# Out:
#                 Area       City             Restaurant  Price  Avg ratings  \
# 0              Udhna      Surat            Nv Fastfood  150.0          4.0
# 1    Sector 3 Rohini      Delhi           Pizzallo Hot  400.0          3.0
# 2       Himayatnagar  Hyderabad          Huber & Holly  500.0          4.2
# 3       Gulbai Tekra  Ahmedabad           Hocco Eatery  400.0          4.4
# 4     Himayath Nagar  Hyderabad  Krishna Idli And Dosa  250.0          3.9
# ..               ...        ...                    ...    ...          ...
# 481         Jadavpur    Kolkata            Go 69 Pizza  250.0          2.9
# 482            Garfa    Kolkata              Happizzaa  350.0          4.0
# 483        Annanagar    Chennai        Pizza Mechanics  200.0          2.9
# 484         Jadavpur    Kolkata                    Cfk  500.0          2.9
# 485        Lake Town    Kolkata          Kolkata Pizza  159.0          2.9
#
# ...

# %%
food_type_pizzas_fast_delivery_df=food_type_pizzas_fast_delivery_df.head(10)

# %%
food_type_pizzas_fast_delivery_df
# Out:
#                 Area       City             Restaurant  Price  Avg ratings  \
# 0              Udhna      Surat            Nv Fastfood  150.0          4.0
# 1    Sector 3 Rohini      Delhi           Pizzallo Hot  400.0          3.0
# 2       Himayatnagar  Hyderabad          Huber & Holly  500.0          4.2
# 3       Gulbai Tekra  Ahmedabad           Hocco Eatery  400.0          4.4
# 4     Himayath Nagar  Hyderabad  Krishna Idli And Dosa  250.0          3.9
# 5  Central Bangalore  Bangalore         Domino'S Pizza  400.0          4.1
# 6         Somwarpeth       Pune         Domino'S Pizza  400.0          2.9
# 7         Kurla West     Mumbai         Domino'S Pizza  400.0          4.0
# 8          Kachiguda  Hyderabad         Domino'S Pizza  400.0          4.4
# 9        Ellisbridge  Ahmedabad         Domino'S Pizza  400.0          4.4
#
#    Total ratings                                          Food type  \
# 0            100  Fast Food,North Indian,Chinese,South Indian,Sn...
# ...

# %%
sns.barplot(x=food_type_pizzas_fast_delivery_df['Restaurant'],y=food_type_pizzas_fast_delivery_df['Delivery time'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=food_type_pizzas_fast_delivery_df['City'],y=food_type_pizzas_fast_delivery_df['Delivery time'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=food_type_pizzas_fast_delivery_df['Restaurant'],y=food_type_pizzas_fast_delivery_df['Delivery time'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Total Number of Resturants for Food type Pizzas with Low Prices

# %%
food_type_pizzas_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 8                                         Tea Brew  350.0          4.1
# 67                                       Chaipatty  200.0          3.9
# 108                                       Us Pizza  200.0          3.2
# 111                                     Frosty Den  200.0          2.2
# ...

# %%
low_price_df=food_type_pizzas_df[['Area','City','Restaurant','Price']]

# %%
low_price_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Price
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0
# 8                                         Tea Brew  350.0
# 67                                       Chaipatty  200.0
# 108                                       Us Pizza  200.0
# 111                                     Frosty Den  200.0
# ...                                            ...    ...
# 8649                               Tropical Fusion  200.0
# ...

# %%
low_price_df=low_price_df.sort_values(by="Price")

# %%
low_price_df=low_price_df[:10]

# %%
low_price_df
# Out:
#                 Area       City                  Restaurant  Price
# 8483       Annanagar    Chennai              Spotlight Cafe   50.0
# 3816     Toli Chowki  Hyderabad         Bakewell Cake House  100.0
# 8120      Pitam Pura      Delhi              The Pizza Club  100.0
# 7706      Ganga Dham       Pune               Rj'S Sandwich  100.0
# 7448         Isanpur  Ahmedabad            Kutchi Karnavati  100.0
# 2079           Athwa      Surat     Shree Sainath Fast Food  100.0
# 8527  Marol Sakinaka     Mumbai                   Bite Cafe  100.0
# 6319       Maninagar  Ahmedabad        New Karnavati Dabeli  100.0
# 3302      Triplicane    Chennai                Cake Galatta  100.0
# 8607          Piplod      Surat  Zorko Brand Of Food Lovers  100.0

# %%
sns.barplot(x=low_price_df['City'],y=low_price_df['Price'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='Price'>

# %%
sns.barplot(x=low_price_df['Area'],y=low_price_df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=low_price_df['Restaurant'],y=low_price_df['Price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Total Number of Resturants for Food type Pizzas with High Average Rating

# %%
high_avg_rating_df=food_type_pizzas_df[['Area','City','Restaurant','Avg ratings']]

# %%
high_avg_rating_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Avg ratings
# 7     Cupcake Noggins - Cakespastries And Desserts          4.3
# 8                                         Tea Brew          4.1
# 67                                       Chaipatty          3.9
# 108                                       Us Pizza          3.2
# 111                                     Frosty Den          2.2
# ...                                            ...          ...
# ...

# %%
high_avg_rating_df=high_avg_rating_df.sort_values(by="Avg ratings",ascending=False)

# %%
high_avg_rating_df=high_avg_rating_df[:10]

# %%
high_avg_rating_df
# Out:
#                Area       City             Restaurant  Avg ratings
# 6297            Nsp      Delhi              Fat Tiger          5.0
# 1878         Rohini      Delhi  Pizza Paradise By Vhc          4.8
# 972          Bopodi       Pune           Rosso Bianco          4.8
# 3783        Kilpauk    Chennai          Pastry Maniaa          4.7
# 1781  Koregaon Park       Pune           Yonies Pizza          4.6
# 1842   Nungambakkam    Chennai             Crisp Cafe          4.6
# 1856  Koregaon Park       Pune          Huber & Holly          4.6
# 6524        Kilpauk    Chennai            Bombaysthan          4.6
# 3746       Perambur    Chennai  Chennai Classic Cakes          4.6
# 827       Vastrapur  Ahmedabad          The Blue Oven          4.5

# %%
sns.barplot(x=high_avg_rating_df['Restaurant'],y=high_avg_rating_df['Avg ratings'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=high_avg_rating_df['City'],y=high_avg_rating_df['Avg ratings'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=high_avg_rating_df['Area'],y=high_avg_rating_df['Avg ratings'])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %% [markdown]
# # Find Minimum Average Delivery Time for restaurant for Pizza by City and Area

# %%
food_type_pizzas_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 8                                         Tea Brew  350.0          4.1
# 67                                       Chaipatty  200.0          3.9
# 108                                       Us Pizza  200.0          3.2
# 111                                     Frosty Den  200.0          2.2
# ...

# %%
for index,value in enumerate(food_type_pizzas_df['Food type']):
    print(index,value)
# Out:
# 0 Desserts,British,Bakery,Pizzas,Snacks
# 1 American,Italian,Beverages,Continental,Chinese,Pastas,Pizzas,Fast Food
# 2 Fast Food,Beverages,Pizzas,Street Food,Snacks
# 3 Italian,Pizzas,Fast Food,Beverages,Desserts
# 4 Ice Cream,Pizzas,Fast Food,Beverages,Desserts
# 5 Italian,Pizzas,Fast Food
# 6 Italian,Pizzas,Pastas,Desserts,Continental,Salads
# 7 Italian,Pizzas
# 8 Desserts,Asian,Beverages,Bakery,Italian,Continental,Pizzas,Italian-American
# 9 Italian,Pizzas,Fast Food
# 10 Pizzas,Fast Food
# 11 Pizzas
# 12 Italian,Pizzas,Fast Food
# 13 Pizzas
# 14 Pizzas,Italian,Pastas
# 15 Pizzas,Italian
# 16 Pizzas,Italian
# 17 Pizzas,Fast Food
# 18 Fast Food,Combo,Salads,Pizzas,Italian,Continental,European,Mediterranean,Desserts
# 19 Pizzas,Italian,Pastas,Chinese
# 20 Pizzas
# 21 Pizzas
# 22 Pizzas
# 23 North Indian,Continental,Indian,Tandoor,Oriental,Chinese,Pastas,Pizzas
# 24 Pizzas,Italian
# 25 Pizzas
# 26 Italian,Pizzas,Desserts,Beverages,Combo
# 27 American,Pizzas,Continental
# ...

# %%
label_df=food_type_pizzas_df.groupby("City")['Delivery time'].mean().sort_values(ascending=True).index

# %%
value_df=food_type_pizzas_df.groupby("City")['Delivery time'].mean().sort_values(ascending=True).values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %%
label_df=food_type_pizzas_df.groupby("Area")['Delivery time'].mean().sort_values(ascending=True).index

# %%
value_df=food_type_pizzas_df.groupby("Area")['Delivery time'].mean().sort_values(ascending=True).values

# %%
plt.pie(x=value_df[:10],labels=label_df[:10],autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=label_df[:10],y=value_df[:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Total Number of Resturants Offering Food Type pizzas in Bangalore with good Avg rating

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
food_type_pizzas_df=df[df['Food type pizzas']==1]

# %%
food_type_pizzas_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 8                                         Tea Brew  350.0          4.1
# 67                                       Chaipatty  200.0          3.9
# 108                                       Us Pizza  200.0          3.2
# 111                                     Frosty Den  200.0          2.2
# ...

# %%
food_type_pizzas_df=food_type_pizzas_df[food_type_pizzas_df['City']=="Bangalore"]

# %%
food_type_pizzas_df
# Out:
#                    Area       City  \
# 7           Koramangala  Bangalore
# 8                Domlur  Bangalore
# 67          Indiranagar  Bangalore
# 230         Ashok Nagar  Bangalore
# 277    Langford Gardens  Bangalore
# 507        Basavanagudi  Bangalore
# 564         Ashok Nagar  Bangalore
# 585   Central Bangalore  Bangalore
# 1632        Koramangala  Bangalore
# 1861      Shivaji Nagar  Bangalore
# 2115      Richmond Town  Bangalore
# 2906        Koramangala  Bangalore
# 2968        Indiranagar  Bangalore
# 3074        Koramangala  Bangalore
# 3167            Ejipura  Bangalore
# 3179    New Tippasandra  Bangalore
# 3195        Ashok Nagar  Bangalore
# 3214        Koramangala  Bangalore
# 3226      Shivaji Nagar  Bangalore
# 3239      Shivaji Nagar  Bangalore
# 3324        Indiranagar  Bangalore
# 3994            Ejipura  Bangalore
# 4254        Koramangala  Bangalore
# 4668  Central Bangalore  Bangalore
# 4669  Central Bangalore  Bangalore
# ...

# %%
food_type_pizzas_df=food_type_pizzas_df[['Area','Restaurant','Price','Food type','Avg ratings']]

# %%
food_type_pizzas_df
# Out:
#                    Area                                    Restaurant  Price  \
# 7           Koramangala  Cupcake Noggins - Cakespastries And Desserts  150.0
# 8                Domlur                                      Tea Brew  350.0
# 67          Indiranagar                                     Chaipatty  200.0
# 230         Ashok Nagar                                         Smoor  300.0
# 277    Langford Gardens                                     Pizza Hut  600.0
# 507        Basavanagudi                                    Cafe Mondo  500.0
# 564         Ashok Nagar                                     Hoppipola  600.0
# 585   Central Bangalore                                Domino'S Pizza  400.0
# 1632        Koramangala                              The Bier Library  600.0
# 1861      Shivaji Nagar                               Main Lassi Shop  250.0
# 2115      Richmond Town                                   Wandercrust  350.0
# ...

# %%
food_type_pizzas_df=food_type_pizzas_df.reset_index(drop=True)

# %%
food_type_pizzas_df=food_type_pizzas_df.sort_values(by="Avg ratings",ascending=False)

# %%
food_type_pizzas_df
# Out:
#                  Area                                    Restaurant  Price  \
# 11        Koramangala                                 Xoox Brewmill  500.0
# 22        Koramangala                              Brown Burger Co.  300.0
# 17        Koramangala                              The Circle Dream  500.0
# 5        Basavanagudi                                    Cafe Mondo  500.0
# 8         Koramangala                              The Bier Library  600.0
# 13        Koramangala                              That Pizza Place  500.0
# 0         Koramangala  Cupcake Noggins - Cakespastries And Desserts  150.0
# 3         Ashok Nagar                                         Smoor  300.0
# 33  Central Bangalore                             The Chaap Factory  300.0
# 14            Ejipura                         The Downtown Pizzeria  200.0
# 7   Central Bangalore                                Domino'S Pizza  400.0
# ...

# %%
sns.barplot(x=food_type_pizzas_df['Restaurant'][:10],y=food_type_pizzas_df['Avg ratings'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Total Number of Resturants Offering Food Type pizzas in Bangalore with Fast Delivery

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
food_type_pizzas_df=df[df['Food type pizzas']==1]

# %%
food_type_pizzas_df
# Out:
#                         Area       City  \
# 7                Koramangala  Bangalore
# 8                     Domlur  Bangalore
# 67               Indiranagar  Bangalore
# 108                  Adikmet  Hyderabad
# 111                  Adikmet  Hyderabad
# ...                      ...        ...
# 8649                  Piplod      Surat
# 8666              Laldarwaja  Ahmedabad
# 8670                  Rohini      Delhi
# 8671          Himayath Nagar  Hyderabad
# 8675  Panjarapole Cross Road  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 8                                         Tea Brew  350.0          4.1
# 67                                       Chaipatty  200.0          3.9
# 108                                       Us Pizza  200.0          3.2
# 111                                     Frosty Den  200.0          2.2
# ...

# %%
food_type_pizzas_df=food_type_pizzas_df[food_type_pizzas_df['City']=="Bangalore"]

# %%
food_type_pizzas_df
# Out:
#                    Area       City  \
# 7           Koramangala  Bangalore
# 8                Domlur  Bangalore
# 67          Indiranagar  Bangalore
# 230         Ashok Nagar  Bangalore
# 277    Langford Gardens  Bangalore
# 507        Basavanagudi  Bangalore
# 564         Ashok Nagar  Bangalore
# 585   Central Bangalore  Bangalore
# 1632        Koramangala  Bangalore
# 1861      Shivaji Nagar  Bangalore
# 2115      Richmond Town  Bangalore
# 2906        Koramangala  Bangalore
# 2968        Indiranagar  Bangalore
# 3074        Koramangala  Bangalore
# 3167            Ejipura  Bangalore
# 3179    New Tippasandra  Bangalore
# 3195        Ashok Nagar  Bangalore
# 3214        Koramangala  Bangalore
# 3226      Shivaji Nagar  Bangalore
# 3239      Shivaji Nagar  Bangalore
# 3324        Indiranagar  Bangalore
# 3994            Ejipura  Bangalore
# 4254        Koramangala  Bangalore
# 4668  Central Bangalore  Bangalore
# 4669  Central Bangalore  Bangalore
# ...

# %%
food_type_pizzas_df=food_type_pizzas_df[['Area','Restaurant','Price','Food type','Delivery time']]

# %%
food_type_pizzas_df
# Out:
#                    Area                                    Restaurant  Price  \
# 7           Koramangala  Cupcake Noggins - Cakespastries And Desserts  150.0
# 8                Domlur                                      Tea Brew  350.0
# 67          Indiranagar                                     Chaipatty  200.0
# 230         Ashok Nagar                                         Smoor  300.0
# 277    Langford Gardens                                     Pizza Hut  600.0
# 507        Basavanagudi                                    Cafe Mondo  500.0
# 564         Ashok Nagar                                     Hoppipola  600.0
# 585   Central Bangalore                                Domino'S Pizza  400.0
# 1632        Koramangala                              The Bier Library  600.0
# 1861      Shivaji Nagar                               Main Lassi Shop  250.0
# 2115      Richmond Town                                   Wandercrust  350.0
# ...

# %%
food_type_pizzas_df=food_type_pizzas_df.reset_index(drop=True)

# %%
food_type_pizzas_df=food_type_pizzas_df.sort_values(by="Delivery time",ascending=True)

# %%
food_type_pizzas_df
# Out:
#                  Area                                    Restaurant  Price  \
# 7   Central Bangalore                                Domino'S Pizza  400.0
# 32  Central Bengalore                                 Zed The Baker  500.0
# 6         Ashok Nagar                                     Hoppipola  600.0
# 42  Central Bangalore                        Lakshmi Super Sandwich  149.0
# 4    Langford Gardens                                     Pizza Hut  600.0
# 9       Shivaji Nagar                               Main Lassi Shop  250.0
# 38       Shanti Nagar                            The Bangalore Cafe  400.0
# 10      Richmond Town                                   Wandercrust  350.0
# 18      Shivaji Nagar                                     U.S Pizza  400.0
# 19      Shivaji Nagar                               Al Pizza Corner  250.0
# 25        Shantinagar                              Oven Story Pizza  600.0
# ...

# %%
sns.barplot(x=food_type_pizzas_df['Restaurant'][:10],y=food_type_pizzas_df['Delivery time'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Count the Maximum number  of Resturants offering Food Type Pizzas in all City

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
food_type_pizzas_df=df[df['Food type pizzas']==1]

# %%
food_type_pizzas_df=food_type_pizzas_df.reset_index(drop=True)

# %%
label_df=food_type_pizzas_df['City'].value_counts().index

# %%
value_df=food_type_pizzas_df['City'].value_counts().values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
sns.barplot(x=label_df,y=value_df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Total number of Resturants offering Food Type Pizzas in all City

# %%
food_type_pizzas_df
# Out:
#                        Area       City  \
# 0               Koramangala  Bangalore
# 1                    Domlur  Bangalore
# 2               Indiranagar  Bangalore
# 3                   Adikmet  Hyderabad
# 4                   Adikmet  Hyderabad
# ..                      ...        ...
# 481                  Piplod      Surat
# 482              Laldarwaja  Ahmedabad
# 483                  Rohini      Delhi
# 484          Himayath Nagar  Hyderabad
# 485  Panjarapole Cross Road  Ahmedabad
#
#                                        Restaurant  Price  Avg ratings  \
# 0    Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 1                                        Tea Brew  350.0          4.1
# 2                                       Chaipatty  200.0          3.9
# 3                                        Us Pizza  200.0          3.2
# 4                                      Frosty Den  200.0          2.2
# ...

# %%
food_type_pizzas_df['Food type pizzas'].sum()
# Out:
# 486

# %% [markdown]
# # Total number of Resturants not offering Food Type Pizzas in all City

# %%
df
# Out:
#                         Area       City  \
# 0                Koramangala  Bangalore
# 1                Koramangala  Bangalore
# 2                  Jogupalya  Bangalore
# 4                Indiranagar  Bangalore
# 7                Koramangala  Bangalore
# ...                      ...        ...
# 8675  Panjarapole Cross Road  Ahmedabad
# 8676                  Rohini      Delhi
# 8677                  Rohini      Delhi
# 8678                  Rohini      Delhi
# 8679             Navrangpura  Ahmedabad
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 2                                          Kim Lee  650.0          4.4
# 4                                              Nh8  350.0          4.0
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# ...

# %%
food_type_not_pizzas_df=df[df['Food type pizzas']==0]

# %%
food_type_not_pizzas_df
# Out:
#              Area       City                                       Restaurant  \
# 0     Koramangala  Bangalore                                      Tandoor Hut
# 1     Koramangala  Bangalore                                    Tunday Kababi
# 2       Jogupalya  Bangalore                                          Kim Lee
# 4     Indiranagar  Bangalore                                              Nh8
# 10    Koramangala  Bangalore                              Bamey'S Restro Cafe
# ...           ...        ...                                              ...
# 8674        Athwa      Surat  Panditjis Dilliwale Chhole Bhature & Dilli Chat
# 8676       Rohini      Delhi                         Jay Mata Ji Home Kitchen
# 8677       Rohini      Delhi                             Chinese Kitchen King
# 8678       Rohini      Delhi                           Shree Ram Paratha Wala
# 8679  Navrangpura  Ahmedabad                                     Sassy Street
#
# ...

# %%
food_type_not_pizzas_df['Food type pizzas'].value_counts()
# Out:
# 0    6532
# Name: Food type pizzas, dtype: int64
